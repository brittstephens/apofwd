# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from glob import glob
import yaml

import cftime

import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

import intake

import regrid_tools
import config
import util

# %% [markdown]
# # Read FOSI simulation
#
# Run details from README
# ```text
# Monthly restarts for POP & CICE come from a modified* OMIP2 (JRA55-do forcing) spinup (6 cycles)
# FOSI (forced ocean--sea-ice) simulation. Details of this simulation are as follows:
#     - CASE: g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005
#     - CASEROOT: /glade/work/klindsay/cesm22_cases/SMYLE/$CASE
#     - SRCROOT: /glade/work/klindsay/cesm2_tags/cesm2.2.0/
#     - forcing:  JRA55-do v1.4, 1958-2018 (==> 61-year cycle)
#     - spinup: 6 cycles (==> simyears 0001-0366)
#     - years used for SMYLE ICs:   0306 (1958) - 0366 (2018)
#
# * Modifications from CMIP6-OMIP2 were made to improve sea-ice and ocean BGC fields:
#     -Use of full 1958-2018 (61-year) forcing cycle during spinup
#     -Use of strong under-ice restoring to model prognostic freezing temperature (TFZ)
#     -Reduced deep isopycnal mixing (kappa_isop_deep = 0.1, instead of CESM2-default of 0.2)
#     -Enhanced sea ice albedoes:
#             r_snw = 1.6
#             dt_mlt = 0.5
#             rsnw_mlt = 1000.
# ```

# %%
year_range = 1984, 2020

# %%
src_grid = regrid_tools.grid("POP_gx1v7")
src_grid
# Out:
# writing: /glade/derecho/scratch/stephens/tmp/regridding/POP_gx1v7.nc
# grid: POP_gx1v7
# dims: (384, 320)
# file: /glade/derecho/scratch/stephens/tmp/regridding/POP_gx1v7.nc

# %%
dst_grid = regrid_tools.grid("latlon", **config.config_dict["flux-dst-grid-kwargs"])
dst_grid
# Out:
# exists: /glade/derecho/scratch/stephens/tmp/regridding/latlon_1.0x1.0_lon0=-180.0.nc
# grid: latlon_latlon_1.0x1.0_lon0=-180.0
# dims: (180, 360)
# file: /glade/derecho/scratch/stephens/tmp/regridding/latlon_1.0x1.0_lon0=-180.0.nc

# %%
regrid_obj = regrid_tools.regridder(src_grid, dst_grid, method="conserve", clobber=False)
regrid_obj
# Out:
# generating: /glade/derecho/scratch/stephens/tmp/regridding/POP_gx1v7_to_latlon_latlon_1.0x1.0_lon0=-180.0_conserve_extrap-none.nc
#  Starting weight generation with these inputs:
#    Source File: /glade/derecho/scratch/stephens/tmp/regridding/POP_gx1v7.nc
#    Destination File: /glade/derecho/scratch/stephens/tmp/regridding/latlon_1.0x1.0_lon0=-180.0.nc
#    Weight File: /glade/derecho/scratch/stephens/tmp/regridding/POP_gx1v7_to_latlon_latlon_1.0x1.0_lon0=-180.0_conserve_extrap-none.nc
#    Source File is in SCRIP format
#    Source Grid is a global grid
#    Source Grid is a logically rectangular grid
#    Use the center coordinates of the source grid to do the regrid
#    Destination File is in SCRIP format
#    Destination Grid is a global grid
#    Destination Grid is a logically rectangular grid
#    Use the center coordinates of the destination grid to do the regrid
#    Regrid Method: conserve
#    Pole option: NONE
#    Ignore unmapped destination points
#    Output weight file in NetCDF4 file format
#    Line Type: greatcircle
#    Norm Type: dstarea
#    Extrap. Method: none
#
#  Completed weight generation successfully.
#
#
# source grid dims: (384, 320)
# destination grid dims: (180, 360)
# regridder POP_gx1v7.nc --> latlon_1.0x1.0_lon0=-180.0.nc

# %%
dso_grid = util.generate_latlon_grid(**config.config_dict["flux-dst-grid-kwargs"])[["area"]]
dso_grid
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360)
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
# Data variables:
#     area     (lat, lon) float64 1.079e+08 1.079e+08 ... 1.079e+08 1.079e+08

# %%
time_daily, time_daily_bnds = util.gen_daily_cftime_coord(year_range)
time_daily_num = cftime.date2num(time_daily, time_daily.encoding['units'])
time_daily
# Out:
# <xarray.DataArray 'time' (time: 13515)>
# array([cftime.DatetimeGregorian(1984, 1, 1, 12, 0, 0, 0, has_year_zero=False),
#        cftime.DatetimeGregorian(1984, 1, 2, 12, 0, 0, 0, has_year_zero=False),
#        cftime.DatetimeGregorian(1984, 1, 3, 12, 0, 0, 0, has_year_zero=False),
#        ...,
#        cftime.DatetimeGregorian(2020, 12, 29, 12, 0, 0, 0, has_year_zero=False),
#        cftime.DatetimeGregorian(2020, 12, 30, 12, 0, 0, 0, has_year_zero=False),
#        cftime.DatetimeGregorian(2020, 12, 31, 12, 0, 0, 0, has_year_zero=False)],
#       dtype=object)
# Dimensions without coordinates: time
# Attributes:
#     bounds:   time_bnds

# %%
curator = util.curate_flux_products()
curator
# Out:
# {'description': 'Flux products for transport modeling', 'plugins': {'source': [{'module': 'intake_xarray'}]}, 'sources': {'SFAPO_OCN.carboscope.apo99X_v2021': {'args': {'urlpath': '/glade/work/stephens/sno-analysis/flux-products-staging/SFAPO_OCN.CarboScope.apo99X_v2021.nc', 'xarray_kwargs': {'decode_times': False}}, 'description': 'APO fluxes from CarboScope inversion apo99X_v2021', 'driver': 'netcdf'}, 'SFCO2_FF.GCP-GridFED.v2021.3': {'args': {'urlpath': '/glade/work/mclong/sno-analysis/flux-products/SFCO2_FF.GCP-GridFED.v2021.3.19840101-20201231.nc', 'xarray_kwargs': {'decode_times': False}}, 'description': 'Gridded fossil CO2 emissions consistent with national inventories 1959-2020', 'driver': 'netcdf'}, 'SFCO2_FF.OCO2-MIP.v2020.1': {'args': {'urlpath': '/glade/work/stephens/sno-analysis/flux-products-staging/SFCO2_FF.OCO2-MIP-FF.v2020.1.20000101-20201231.nc', 'xarray_kwargs': {'decode_times': False}}, 'description': 'daily integral of Fossil Fuel CO₂ Emissions for the OCO2 Model Intercomparison Project (MIP)', 'driver': 'netcdf'}, 'SFCO2_OCN.MPI-SOM-FFN': {'args': {'urlpath': '/glade/work/mclong/sno-analysis/flux-products/SFCO2_OCN.MPI-SOM-FFN.v2021.198401-202012.nc', 'xarray_kwargs': {'decode_times': False}}, 'description': 'An observation-based global monthly gridded sea surface pCO2 product from 1982 onward and its monthly climatology. Citation: Landschützer, P., Gruber, N., Bakker, D. C. E.: Decadal variations and trends of the global ocean carbon sink, Global Biogeochemical Cycles, 30, doi:10.1002/2015GB005359, 2016', 'driver': 'netcdf'}, 'SFCO2_OCN.cesm_fosi_smyle': {'args': {'urlpath': '/glade/work/mclong/sno-analysis/flux-products/SFCO2_OCN.g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.19840101-20201231.nc', 'xarray_kwargs': {'decode_times': False}}, 'description': 'CESM simulated flux from g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005 at daily resolution', 'driver': 'netcdf'}, 'SFN2_OCN.cesm_fosi_smyle': {'args': {'urlpath': '/glade/work/mclong/sno-analysis/flux-products/SFN2_OCN.g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.19840101-20201231.nc', 'xarray_kwargs': {'decode_times': False}}, 'description': 'CESM simulated flux from g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005 at monthly resolution', 'driver': 'netcdf'}, 'SFN2_OCN.era5_shf': {'args': {'urlpath': '/glade/work/mclong/sno-analysis/flux-products/SFN2_OCN.era5-shf.shft_0d.scale_0.77.1984-2020.nc', 'xarray_kwargs': {'decode_times': False}}, 'description': 'N2 flux computed from ERA5 heat flux', 'driver': 'netcdf'}, 'SFO2_FF.GCP-GridFED.v2021.3': {'args': {'urlpath': '/glade/work/mclong/sno-analysis/flux-products/SFO2_FF.GCP-GridFED.v2021.3.19840101-20201231.nc', 'xarray_kwargs': {'decode_times': False}}, 'description': 'Gridded fossil O2 combustion consistent with national inventories 1959-2020', 'driver': 'netcdf'}, 'SFO2_OCN.cesm_fosi_smyle': {'args': {'urlpath': '/glade/work/mclong/sno-analysis/flux-products/SFO2_OCN.g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.19840101-20201231.nc', 'xarray_kwargs': {'decode_times': False}}, 'description': 'CESM simulated flux from g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005 at daily resolution', 'driver': 'netcdf'}, 'SFO2_OCN.gk2001_R2016': {'args': {'urlpath': '/glade/work/mclong/sno-analysis/flux-products/SFO2_OCN.GK2001.monclim.shft_0d.scale_0.82.R2016_ann.nc', 'xarray_kwargs': {'decode_times': False}}, 'description': 'GK2001 seasional fluxes with R2016 annual mean; time axis shifted by 0.0d, fluxes scaled by 0.82', 'driver': 'netcdf'}}}

# %%
use_dask = False

if use_dask:
    cluster, client = util.get_ClusterClient()
    cluster.scale(12)
    client

# %%
year_offset = 2018 - 366
year_offset
# Out:
# 1652

# %%
# %%time
clobber = True

path = '/glade/campaign/cesm/development/espwg/SMYLE/initial_conditions/SMYLE-FOSI/ocn/proc/tseries'
case = 'g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005'

xr_open_kwargs = dict(chunks={'nlat': 16}, 
                      decode_coords=False, 
                      decode_times=False,
                     )

cesm_varnames = {
    "SFCO2_OCN": {"varname": "FG_CO2_2", "freq": "day_1", "stream": "pop.h.ecosys.nday1"},
    "SFO2_OCN": {"varname": "STF_O2_2", "freq": "day_1", "stream": "pop.h.ecosys.nday1"},
    "SFN2_OCN": {"varname": ["SHF", "SALT", "TEMP"], "freq": "month_1", "stream": "pop.h"},
}



nmolcm2s_molm2s = 1e-9 * 1e4

variables = ['SFCO2_OCN', 'SFO2_OCN', 'SFN2_OCN']

fgn2_scaleby = 1 / 1.3

dsets = {}
for v in variables:
    
    # output file
    file_out = f"{config.flux_product_dir}/{v}.{case}.{year_range[0]}0101-{year_range[1]}1231.nc"    
    
    if os.path.exists(file_out) and not clobber:
        print(f'exists: {file_out}')
        dsets[v] = xr.open_dataset(file_out)
        continue

    # get variable, stream and frequency
    varname = cesm_varnames[v]['varname']
    stream = cesm_varnames[v]['stream'] 
    freq = cesm_varnames[v]['freq']
    
    if freq == 'day_1':
        freq_str = 'daily'
        dateglob = '????????-????????'
    elif freq == 'month_1':
        freq_str = 'monthly'        
        dateglob = '??????-??????'
    

    # if varname is a list, assume it's a derived variable
    if isinstance(varname, list):
        ds_list = []
        for varname_i in varname:
            file = sorted(glob(f'{path}/{freq}/{case}.{stream}.{varname_i}.{dateglob}.nc'))
            assert len(file) == 1   
            ds_list.append(xr.open_dataset(file[0], **xr_open_kwargs))
        ds = xr.merge(ds_list)
        
        if v == 'SFN2_OCN':
            ds = ds.isel(z_t=0, drop=True).rename({'SHF': 'hfds', 'SALT': 'sos', 'TEMP': 'tos'})
            ds = util.compute_fgn2(ds, scaleby=fgn2_scaleby).drop(['hfds', 'sos', 'tos'])
            ds = ds.rename({'fgn2': 'SFN2_OCN'})
            ds.SFN2_OCN.attrs['units'] = 'mol/m^2/s'
        
        # append Jan from the last year of the simulation
        # so that the interpolation doesn't yeild NaNs
        if freq == 'month_1':
            assert 'days since' in ds.time.attrs['units']
            ds_jan_last = ds.isel(time=[-12])
            ds_jan_last['time'] = ds_jan_last.time + 365.
            ds_jan_last['time_bound'][0, :] = ds_jan_last.time_bound[0, :] + 365.
            ds = xr.concat((ds, ds_jan_last), dim='time')
    else:
        file = sorted(glob(f'{path}/{freq}/{case}.{stream}.{varname}.{dateglob}.nc'))
        assert len(file) == 1           
        ds = xr.open_dataset(file[0], **xr_open_kwargs).rename({varname: v})
    
    time_bounds = ds[ds.time.bounds]

    # add year offset, change calendar to gregorian
    time_noleap = cftime.num2date(time_bounds.mean(axis=1), units=ds.time.units, calendar=ds.time.calendar)
    time_components = util.gen_time_components_variable(time_noleap, year_offset)
    
    time_gregorian_date = [
        cftime.DatetimeGregorian(*time_components[i, :]) 
        for i in range(time_components.shape[0])
    ]    
    time_gregorian_num = cftime.date2num(time_gregorian_date, units=time_daily.encoding['units'])
    ds['time'] = xr.DataArray(time_gregorian_num, dims=('time'))

    # interpolate to daily time (with leap days)
    ds = ds.interp(time=time_daily_num)
    ds['time'] = time_daily

    # subset variable, reverse sign convention
    ds = ds[[v]]    
    if v in ['SFCO2_OCN', 'SFO2_OCN',]:
        with xr.set_options(keep_attrs=True):
            ds[v] = -1.0 * nmolcm2s_molm2s * ds[v]
        ds[v].attrs['units'] = 'mol/m^2/s'
    
    # regrid
    dso = regrid_obj(ds.compute())
    dso[v] = dso[v].rename({'nlat': 'lat', 'nlon': 'lon'})    
    for attr in ['coordinates', 'grid_loc', 'cell_methods']:
        if attr in dso[v].attrs:
            del dso[v].attrs[attr]
        
    dso["time"] = ds.time    
    dso[ds.time.bounds] = time_daily_bnds
    dso['lat'] = dso_grid['lat']
    dso['lon'] = dso_grid['lon']    
    dso['area'] = dso_grid['area']    

    # clean up attributes
    attrs_keys = list(dso.attrs.keys())
    for attr in attrs_keys:
        if attr not in ['model_doi_url']:
            del dso.attrs[attr]
    dso.attrs['source'] = case
    dso.attrs['note'] = 'Leap day values are linearly interpolated from adjacent data'

    # remove existing output
    if os.path.exists(file_out):
        print(f'removing: {file_out}')        
        os.remove(file_out)
    
    util.to_netcdf_clean(dso, file_out, format='NETCDF4')
    
    dsets[v] = dso
    curator.add_source(
        key=f"{v}.cesm_fosi_smyle",
        urlpath=file_out,
        description=f'CESM simulated flux from {case} at {freq_str} resolution',
    )
# Out:
# ------------------------------
# Writing /glade/work/stephens/sno-analysis/flux-products-staging/SFCO2_OCN.g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.19840101-20201231.nc
# netcdf SFCO2_OCN.g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.19840101-20201231 {
# dimensions:
# 	lon = 360 ;
# 	lat = 180 ;
# 	time = 13515 ;
# 	d2 = 2 ;
# variables:
# 	double lon(lon) ;
# 		lon:units = "degrees_east" ;
# 		lon:long_name = "Longitude" ;
# 	double lat(lat) ;
# 		lat:units = "degrees_north" ;
# 		lat:long_name = "Latitude" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1984-01-01" ;
# 		time:calendar = "standard" ;
# 	float SFCO2_OCN(time, lat, lon) ;
# 		SFCO2_OCN:_FillValue = 9.96921e+36f ;
# 		SFCO2_OCN:long_name = "DIC Surface Gas Flux" ;
# 		SFCO2_OCN:units = "mol/m^2/s" ;
# 	double time_bnds(time, d2) ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m^2" ;
# 		area:long_name = "area" ;
#
# // global attributes:
# 		:model_doi_url = "https://doi.org/10.5065/D67H1H0V" ;
# 		:source = "g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005" ;
# 		:note = "Leap day values are linearly interpolated from adjacent data" ;
# 		:history = "created by https://github.com/brittstephens/apofwd/tree/013724c on 2025-03-08" ;
# }
# format: netCDF-4
# ------------------------------
# ------------------------------
# Writing /glade/work/stephens/sno-analysis/flux-products-staging/SFO2_OCN.g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.19840101-20201231.nc
# netcdf SFO2_OCN.g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.19840101-20201231 {
# dimensions:
# 	lon = 360 ;
# 	lat = 180 ;
# 	time = 13515 ;
# 	d2 = 2 ;
# variables:
# 	double lon(lon) ;
# 		lon:units = "degrees_east" ;
# 		lon:long_name = "Longitude" ;
# 	double lat(lat) ;
# 		lat:units = "degrees_north" ;
# 		lat:long_name = "Latitude" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1984-01-01" ;
# 		time:calendar = "standard" ;
# 	float SFO2_OCN(time, lat, lon) ;
# 		SFO2_OCN:_FillValue = 9.96921e+36f ;
# 		SFO2_OCN:long_name = "Dissolved Oxygen Surface Flux" ;
# 		SFO2_OCN:units = "mol/m^2/s" ;
# 	double time_bnds(time, d2) ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m^2" ;
# 		area:long_name = "area" ;
#
# // global attributes:
# 		:model_doi_url = "https://doi.org/10.5065/D67H1H0V" ;
# 		:source = "g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005" ;
# 		:note = "Leap day values are linearly interpolated from adjacent data" ;
# 		:history = "created by https://github.com/brittstephens/apofwd/tree/013724c on 2025-03-08" ;
# }
# format: netCDF-4
# ------------------------------
# ------------------------------
# Writing /glade/work/stephens/sno-analysis/flux-products-staging/SFN2_OCN.g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.19840101-20201231.nc
# netcdf SFN2_OCN.g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005.19840101-20201231 {
# dimensions:
# 	lon = 360 ;
# 	lat = 180 ;
# 	time = 13515 ;
# 	d2 = 2 ;
# variables:
# 	double lon(lon) ;
# 		lon:units = "degrees_east" ;
# 		lon:long_name = "Longitude" ;
# 	double lat(lat) ;
# 		lat:units = "degrees_north" ;
# 		lat:long_name = "Latitude" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1984-01-01" ;
# 		time:calendar = "standard" ;
# 	float SFN2_OCN(time, lat, lon) ;
# 		SFN2_OCN:_FillValue = 9.96921e+36f ;
# 		SFN2_OCN:units = "mol/m^2/s" ;
# 		SFN2_OCN:long_name = "N2 air-sea flux (computed from heat flux)" ;
# 		SFN2_OCN:note = "fluxes computed using F = c * (-dC/dT) * Q/Cp; c = 0.7692" ;
# 	double time_bnds(time, d2) ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m^2" ;
# 		area:long_name = "area" ;
#
# // global attributes:
# 		:model_doi_url = "https://doi.org/10.5065/D67H1H0V" ;
# 		:source = "g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005" ;
# 		:note = "Leap day values are linearly interpolated from adjacent data" ;
# 		:history = "created by https://github.com/brittstephens/apofwd/tree/013724c on 2025-03-08" ;
# }
# format: netCDF-4
# ------------------------------
# CPU times: user 47min 40s, sys: 1min 43s, total: 49min 24s
# Wall time: 50min 55s

# %%
for key, dsi in dsets.items():    
    v = key
    plt.figure()
    with xr.set_options(keep_attrs=True):    
        global_sum = ((dsi[v] * dsi.area).sum(['lat', 'lon'])) * 1e-12 * 86400.
        global_sum.attrs['units'] = 'Tmol day$^{-1}$'
    global_sum.plot()

# %%
if use_dask:
    client.close()
    cluster.close()
